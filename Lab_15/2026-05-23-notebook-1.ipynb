# %%
# !pip install -q --user streamlit
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# %%writefile app.py

import streamlit as st

st.title("Simple CoCalc Streamlit App")
st.write("Hello! This app is running on CoCalc.")

name = st.text_input("What is your name?")
if name:
    st.write(f"Nice to meet you, {name}!")
# Out:
# Writing app.py

# %%
# !echo $COCALC_PROJECT_ID
# Out:
# 253caafd-8b9c-461f-9f27-55abe628284b

# %%
# !export STREAMLIT_SERVER_BASE_URL_PATH="/${COCALC_PROJECT_ID}/port/8501/"

# %%
# !STREAMLIT_SERVER_BASE_URL_PATH="/${COCALC_PROJECT_ID}/port/8501/" streamlit run app.py
# Out:
# ...
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8504/253caafd-8b9c-461f-9f27-55abe628284b/port/8501
#   Network URL: http://192.168.0.245:8504/253caafd-8b9c-461f-9f27-55abe628284b/port/8501
#   External URL: http://34.139.113.141:8504/253caafd-8b9c-461f-9f27-55abe628284b/port/8501
# ^C
#   Stopping...
